# %% [markdown]
# <a href="https://colab.research.google.com/github/HasanZeynal/Machine-Learning/blob/main/02_credit_fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preperation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ## Checking Duplicated Values

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# ## Checking for Null Values

# %%
for col in df.columns:
  if df[col].isnull().sum() != 0:
    print(f'{col}:{df[col].isnull().sum()}')

# %%
import numpy as np
null_coll = ['V21','V22','V23','V24','V25',
             'V26','V27','V28','Amount']
for col in null_coll:
  df[null_coll] = df[null_coll].replace(np.nan,df[null_coll].mean())
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
print(f"Number of features that has null values {df.isnull().any().sum()}.")
# Out:
# Number of features that has null values 0.

# %%
import numpy as np
df['Class'] = df['Class'].replace({np.nan:1})
# Out:
# <ipython-input-11-aaf7c89adb87>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Class'] = df['Class'].replace({np.nan:1})

# %% [markdown]
# # Data Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Cheking to see imbalance problem

# %%
colors = ['#FFD700','#3B3B3C']
fraud = len(df[df['Class'] == 1]) / len(df) * 100
nofraud = len(df[df['Class'] == 0]) / len(df) * 100
fraud_percentage = [nofraud,fraud]

fig,ax = plt.subplots(nrows = 1,ncols = 2,figsize = (20,5))
plt.subplot(1,2,1)
plt.pie(fraud_percentage,labels = ['Fraud','No Fraud'],autopct='%1.1f%%',startangle = 90,colors = colors,
       wedgeprops = {'edgecolor' : 'black','linewidth': 2,'antialiased' : True})

plt.subplot(1,2,2)
ax = sns.countplot('Class',data = df,edgecolor = 'black',palette = colors)
for rect in ax.patches:
    ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 2, rect.get_height(), horizontalalignment='center', fontsize = 11)
ax.set_xticklabels(['No Fraud','Fraud'])
plt.title('Number of Fraud Cases');
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Correlation

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ba0ba_row0_col0, #T_ba0ba_row1_col1, #T_ba0ba_row2_col2, #T_ba0ba_row3_col3, #T_ba0ba_row4_col4, #T_ba0ba_row5_col5, #T_ba0ba_row6_col6, #T_ba0ba_row7_col7, #T_ba0ba_row8_col8, #T_ba0ba_row9_col9, #T_ba0ba_row10_col10, #T_ba0ba_row11_col11, #T_ba0ba_row12_col12, #T_ba0ba_row13_col13, #T_ba0ba_row14_col14, #T_ba0ba_row15_col15, #T_ba0ba_row16_col16, #T_ba0ba_row17_col17, #T_ba0ba_row18_col18, #T_ba0ba_row19_col19, #T_ba0ba_row20_col20, #T_ba0ba_row21_col21, #T_ba0ba_row22_col22, #T_ba0ba_row23_col23, #T_ba0ba_row24_col24, #T_ba0ba_row25_col25, #T_ba0ba_row26_col26, #T_ba0ba_row27_col27, #T_ba0ba_row28_col28, #T_ba0ba_row29_col29, #T_ba0ba_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col1, #T_ba0ba_row2_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ba0ba_row0_col2, #T_ba0ba_row0_col29, #T_ba0ba_row12_col29 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_ba0ba_row0_col3, #T_ba0ba_row0_col4, #T_ba0ba_row0_col6, #T_ba0ba_row0_col11, #T_ba0ba_row0_col13, #T_ba0ba_row0_col15, #T_ba0ba_row0_col20, #T_ba0ba_row0_col24, #T_ba0ba_row0_col25, #T_ba0ba_row0_col26, #T_ba0ba_row1_col27, #T_ba0ba_row2_col21, #T_ba0ba_row2_col29, #T_ba0ba_row3_col0, #T_ba0ba_row11_col21, #T_ba0ba_row17_col30, #T_ba0ba_row23_col21, #T_ba0ba_row27_col21, #T_ba0ba_row27_col28, #T_ba0ba_row28_col21, #T_ba0ba_row28_col27, #T_ba0ba_row29_col1, #T_ba0ba_row29_col2, #T_ba0ba_row29_col5, #T_ba0ba_row29_col8, #T_ba0ba_row29_col19, #T_ba0ba_row29_col22, #T_ba0ba_row29_col23, #T_ba0ba_row30_col7, #T_ba0ba_row30_col9, #T_ba0ba_row30_col10, #T_ba0ba_row30_col12, #T_ba0ba_row30_col14, #T_ba0ba_row30_col16, #T_ba0ba_row30_col17, #T_ba0ba_row30_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col5, #T_ba0ba_row30_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ba0ba_row0_col7, #T_ba0ba_row4_col0, #T_ba0ba_row8_col14, #T_ba0ba_row12_col14, #T_ba0ba_row16_col14 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col8, #T_ba0ba_row1_col6, #T_ba0ba_row1_col13, #T_ba0ba_row1_col22, #T_ba0ba_row2_col6, #T_ba0ba_row2_col22, #T_ba0ba_row3_col13, #T_ba0ba_row3_col22, #T_ba0ba_row4_col6, #T_ba0ba_row4_col13, #T_ba0ba_row4_col22, #T_ba0ba_row5_col6, #T_ba0ba_row5_col13, #T_ba0ba_row5_col22, #T_ba0ba_row6_col13, #T_ba0ba_row6_col22, #T_ba0ba_row7_col6, #T_ba0ba_row7_col13, #T_ba0ba_row7_col22, #T_ba0ba_row8_col6, #T_ba0ba_row8_col13, #T_ba0ba_row9_col6, #T_ba0ba_row9_col22, #T_ba0ba_row10_col22, #T_ba0ba_row11_col6, #T_ba0ba_row11_col13, #T_ba0ba_row11_col22, #T_ba0ba_row12_col13, #T_ba0ba_row12_col22, #T_ba0ba_row13_col6, #T_ba0ba_row13_col22, #T_ba0ba_row14_col6, #T_ba0ba_row14_col13, #T_ba0ba_row14_col22, #T_ba0ba_row15_col6, #T_ba0ba_row15_col13, #T_ba0ba_row15_col22, #T_ba0ba_row16_col6, #T_ba0ba_row16_col13, #T_ba0ba_row16_col22, #T_ba0ba_row17_col13, #T_ba0ba_row17_col22, #T_ba0ba_row18_col6, #T_ba0ba_row18_col13, #T_ba0ba_row18_col22, #T_ba0ba_row19_col6, #T_ba0ba_row19_col13, #T_ba0ba_row19_col22, #T_ba0ba_row20_col6, #T_ba0ba_row20_col13, #T_ba0ba_row20_col22, #T_ba0ba_row21_col13, #T_ba0ba_row22_col6, #T_ba0ba_row22_col13, #T_ba0ba_row23_col6, #T_ba0ba_row23_col13, #T_ba0ba_row24_col6, #T_ba0ba_row24_col13, #T_ba0ba_row24_col22, #T_ba0ba_row25_col6, #T_ba0ba_row25_col13, #T_ba0ba_row25_col22, #T_ba0ba_row26_col6, #T_ba0ba_row26_col13, #T_ba0ba_row26_col22, #T_ba0ba_row27_col6, #T_ba0ba_row27_col13, #T_ba0ba_row28_col6, #T_ba0ba_row28_col13, #T_ba0ba_row28_col22 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col9, #T_ba0ba_row0_col19, #T_ba0ba_row7_col9, #T_ba0ba_row10_col30 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col10, #T_ba0ba_row0_col22, #T_ba0ba_row1_col29, #T_ba0ba_row2_col11, #T_ba0ba_row3_col12, #T_ba0ba_row4_col11, #T_ba0ba_row5_col12, #T_ba0ba_row6_col11, #T_ba0ba_row7_col12, #T_ba0ba_row8_col12, #T_ba0ba_row9_col11, #T_ba0ba_row9_col12, #T_ba0ba_row15_col11, #T_ba0ba_row18_col12, #T_ba0ba_row19_col11, #T_ba0ba_row20_col11, #T_ba0ba_row21_col11, #T_ba0ba_row22_col11, #T_ba0ba_row23_col11, #T_ba0ba_row24_col11, #T_ba0ba_row25_col11, #T_ba0ba_row26_col11, #T_ba0ba_row29_col11 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col12, #T_ba0ba_row2_col30 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ba0ba_row0_col14, #T_ba0ba_row4_col7, #T_ba0ba_row11_col7, #T_ba0ba_row12_col16, #T_ba0ba_row14_col16, #T_ba0ba_row17_col16, #T_ba0ba_row23_col7, #T_ba0ba_row29_col25 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col16, #T_ba0ba_row1_col30, #T_ba0ba_row5_col10, #T_ba0ba_row9_col30, #T_ba0ba_row12_col10, #T_ba0ba_row15_col0, #T_ba0ba_row17_col10, #T_ba0ba_row20_col10 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col17, #T_ba0ba_row3_col1, #T_ba0ba_row5_col1, #T_ba0ba_row27_col10, #T_ba0ba_row28_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col18, #T_ba0ba_row7_col1, #T_ba0ba_row28_col10 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col21, #T_ba0ba_row1_col19, #T_ba0ba_row2_col19, #T_ba0ba_row3_col19, #T_ba0ba_row4_col19, #T_ba0ba_row5_col19, #T_ba0ba_row6_col19, #T_ba0ba_row7_col19, #T_ba0ba_row8_col19, #T_ba0ba_row9_col19, #T_ba0ba_row10_col19, #T_ba0ba_row11_col19, #T_ba0ba_row12_col19, #T_ba0ba_row13_col19, #T_ba0ba_row14_col19, #T_ba0ba_row14_col20, #T_ba0ba_row15_col19, #T_ba0ba_row17_col19, #T_ba0ba_row18_col19, #T_ba0ba_row20_col19, #T_ba0ba_row21_col19, #T_ba0ba_row21_col20, #T_ba0ba_row22_col19, #T_ba0ba_row23_col19, #T_ba0ba_row24_col19, #T_ba0ba_row25_col19, #T_ba0ba_row26_col19, #T_ba0ba_row27_col19, #T_ba0ba_row28_col19, #T_ba0ba_row28_col20 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col23, #T_ba0ba_row6_col7, #T_ba0ba_row13_col7, #T_ba0ba_row15_col7, #T_ba0ba_row19_col7, #T_ba0ba_row20_col7, #T_ba0ba_row22_col7, #T_ba0ba_row24_col7, #T_ba0ba_row25_col7, #T_ba0ba_row26_col7, #T_ba0ba_row28_col7, #T_ba0ba_row29_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col27, #T_ba0ba_row1_col21, #T_ba0ba_row1_col28, #T_ba0ba_row3_col21, #T_ba0ba_row3_col27, #T_ba0ba_row5_col21, #T_ba0ba_row5_col27, #T_ba0ba_row7_col27, #T_ba0ba_row10_col21, #T_ba0ba_row12_col21, #T_ba0ba_row14_col27, #T_ba0ba_row14_col28, #T_ba0ba_row16_col21, #T_ba0ba_row16_col27, #T_ba0ba_row17_col21, #T_ba0ba_row17_col28, #T_ba0ba_row18_col21, #T_ba0ba_row18_col27, #T_ba0ba_row20_col21, #T_ba0ba_row21_col27, #T_ba0ba_row21_col28, #T_ba0ba_row23_col28, #T_ba0ba_row30_col24 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col28, #T_ba0ba_row4_col21, #T_ba0ba_row6_col21, #T_ba0ba_row9_col21, #T_ba0ba_row13_col21, #T_ba0ba_row15_col21, #T_ba0ba_row19_col21, #T_ba0ba_row24_col21, #T_ba0ba_row25_col21, #T_ba0ba_row26_col21 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ba0ba_row0_col30, #T_ba0ba_row2_col14, #T_ba0ba_row4_col14, #T_ba0ba_row6_col14, #T_ba0ba_row9_col14, #T_ba0ba_row10_col14, #T_ba0ba_row12_col17, #T_ba0ba_row14_col17, #T_ba0ba_row15_col14, #T_ba0ba_row19_col14, #T_ba0ba_row20_col14, #T_ba0ba_row23_col14, #T_ba0ba_row24_col14, #T_ba0ba_row25_col14 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_ba0ba_row1_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ba0ba_row1_col2, #T_ba0ba_row7_col2, #T_ba0ba_row11_col30, #T_ba0ba_row17_col29, #T_ba0ba_row27_col2, #T_ba0ba_row28_col29, #T_ba0ba_row30_col29 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_ba0ba_row1_col3, #T_ba0ba_row2_col0, #T_ba0ba_row5_col3, #T_ba0ba_row9_col0, #T_ba0ba_row10_col3, #T_ba0ba_row12_col3, #T_ba0ba_row17_col3, #T_ba0ba_row27_col3, #T_ba0ba_row28_col0, #T_ba0ba_row29_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ba0ba_row1_col4, #T_ba0ba_row1_col23, #T_ba0ba_row2_col23, #T_ba0ba_row3_col4, #T_ba0ba_row3_col30, #T_ba0ba_row6_col23, #T_ba0ba_row7_col4, #T_ba0ba_row9_col4, #T_ba0ba_row10_col4, #T_ba0ba_row11_col8, #T_ba0ba_row11_col23, #T_ba0ba_row12_col4, #T_ba0ba_row14_col4, #T_ba0ba_row

# %% [markdown]
# ## Cheking for normalization in the each column

# %%
skewed_cols = []
for cols in df.columns:
  if df[cols].dtype != 'object':
    if np.abs(df[cols].skew()) > 1:
      skewed_cols.append(cols)
skewed_cols.remove('Class')
print(skewed_cols)
# Out:
# ['V1', 'V2', 'V3', 'V5', 'V6', 'V7', 'V8', 'V10', 'V12', 'V14', 'V16', 'V17', 'V20', 'V21', 'V23', 'V28', 'Amount']

# %%
colors = ['#B3F9C5', '#f9c5b3']
#first row
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V1'],ax=ax1,color = 'purple')
ax1.set_title('V1')
sns.distplot(df['V2'],ax=ax2,color = 'magenta')
ax2.set_title('V2')
#second
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V3'],ax=ax1,color = 'blue')
ax1.set_title('V3')
sns.distplot(df['V5'],ax=ax2,color='purple')
ax2.set_title('V5')
#third
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V6'],ax=ax1,color = 'blue')
ax1.set_title('V6')
sns.distplot(df['V7'],ax=ax2,color='purple')
ax2.set_title('V7')
#fourth
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V8'],ax=ax1,color = 'blue')
ax1.set_title('V8')
sns.distplot(df['V10'],ax=ax2,color='purple')
ax2.set_title('V10')
#fifth
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V12'],ax=ax1,color = 'blue')
ax1.set_title('V12')
sns.distplot(df['V14'],ax=ax2,color='purple')
ax2.set_title('V14')
#sixth
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V16'],ax=ax1,color = 'blue')
ax1.set_title('V16')
sns.distplot(df['V17'],ax=ax2,color='purple')
ax2.set_title('V17')
#seventh
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V20'],ax=ax1,color = 'blue')
ax1.set_title('V20')
sns.distplot(df['V21'],ax=ax2,color='purple')
ax2.set_title('V21')
#eight
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V23'],ax=ax1,color = 'blue')
ax1.set_title('V23')
sns.distplot(df['V28'],ax=ax2,color='purple')
ax2.set_title('V28')
#nineth
sns.distplot(df['Amount'],ax=ax1,color = 'blue')
ax1.set_title('Amount')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Amount')

# %%
print(f"Skew:{df.Amount.skew()}")
print(f"Max:{df.Amount.max()}\nMin:{df.Amount.min()}")
print(f"Std:{df.Amount.std()}")
# Out:
# Skew:16.978803370060476
# Max:25691.16
# Min:0.0
# Std:250.39943711577337

# %%
corr_of_df = pd.DataFrame(df.corr())
print(f"The corr of time by class is {corr_of_df['Class'][0]}")
# Out:
# The corr of time by class is -0.012359339838080298

# %%
df.drop('Time',axis=1,inplace=True)

# %%
for col in df.columns:
  print(f'{col}:{df[col].min()}')
# Out:
# V1:-56.407509631329
# V2:-72.7157275629303
# V3:-48.3255893623954
# V4:-5.68317119816995
# V5:-113.743306711146
# V6:-26.1605059358433
# V7:-43.5572415712451
# V8:-73.2167184552674
# V9:-13.4340663182301
# V10:-24.5882624372475
# V11:-4.79747346479757
# V12:-18.6837146333443
# V13:-5.79188120632084
# V14:-19.2143254902614
# V15:-4.49894467676621
# V16:-14.1298545174931
# V17:-25.1627993693248
# V18:-9.49874592104677
# V19:-7.21352743017759
# V20:-54.497720494566
# V21:-34.8303821448146
# V22:-10.933143697655
# V23:-44.8077352037913
# V24:-2.83662691870341
# V25:-10.2953970749851
# V26:-2.60455055280817
# V27:-22.5656793207827
# V28:-15.4300839055349
# Amount:0.0
# Class:0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 283726 entries, 0 to 284806
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V1      283726 non-null  float64
#  1   V2      283726 non-null  float64
#  2   V3      283726 non-null  float64
#  3   V4      283726 non-null  float64
#  4   V5      283726 non-null  float64
#  5   V6      283726 non-null  float64
#  6   V7      283726 non-null  float64
#  7   V8      283726 non-null  float64
#  8   V9      283726 non-null  float64
#  9   V10     283726 non-null  float64
#  10  V11     283726 non-null  float64
#  11  V12     283726 non-null  float64
#  12  V13     283726 non-null  float64
#  13  V14     283726 non-null  float64
#  14  V15     283726 non-null  float64
#  15  V16     283726 non-null  float64
#  16  V17     283726 non-null  float64
#  17  V18     283726 non-null  float64
#  18  V19     283726 non-null  float64
#  19  V20     283726 non-null  float64
#  20  V21     283726 non-null  float64
#  21  V22     283726 non-null  float64
#  22  V23     283726 non-null  float64
#  23  V24     283726 non-null  float64
#  24  V25     283726 non-null  float64
#  25  V26     283726 non-null  float64
#  26  V27     283726 non-null  float64
#  27  V28     283726 non-null  float64
#  28  Amount  283726 non-null  float64
#  29  Class   283726 non-null  int64
# dtypes: float64(29), int64(1)
# memory usage: 67.1 MB

# %%
for col in df.columns:
  print(f'{col}:{df[col].skew()}')
# Out:
# V1:-3.273271248440309
# V2:-4.6951619005404694
# V3:-2.1519839570997124
# V4:0.6715041706728241
# V5:-2.414079246966253
# V6:1.829880383771521
# V7:2.890271192715498
# V8:-8.310970330052545
# V9:0.5376630534496958
# V10:1.2529670787468168
# V11:0.34407419325686267
# V12:-2.1990082816149954
# V13:0.06429340464018111
# V14:-1.9188037137586451
# V15:-0.3096590822936595
# V16:-1.0511614715174662
# V17:-3.690497194148406
# V18:-0.24866145737243997
# V19:0.1083118109324772
# V20:-2.0431210560273323
# V21:2.820033113572543
# V22:-0.18232972797521269
# V23:-5.867220791006341
# V24:-0.5521292366718961
# V25:-0.41574386205469593
# V26:0.5802923172348093
# V27:-0.7538039138186547
# V28:11.555115084196773
# Amount:16.978803370060476
# Class:24.430545072372162

# %%
mean_skew = list()
for col in df.columns:
  if col == 'Class':
    continue
  mean_skew.append(np.abs(df[col].skew()))
print(f'The mean of skewness:{(sum(mean_skew)/len(mean_skew))}')
# Out:
# The mean of skewness:2.65821320969485

# %% [markdown]
# # Transformation

# %% [markdown]
# ## Yoe-Johnson and Log Transformation

# %%
df['normalized_amount'] = np.log10(df['Amount'] + 0.01)
# Out:
# <ipython-input-18-0f72232c4dba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_amount'] = np.log10(df['Amount'] + 0.01)

# %%
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['Amount'],ax=ax1)
#plt.text('high skewness')
ax1.set_title('Amount Distribution before Normalization')
sns.distplot(df['normalized_amount'],ax=ax2)
#plt.text('high skewness')
ax2.set_title('Amount Distribution after Log Normalization')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.drop('Amount',axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
skewed_cols.remove('Amount')

# %%
from scipy.stats import yeojohnson
for col in skewed_cols:
    df[col],lam = yeojohnson(df[col])
# Out:
# <ipython-input-19-32d9a1f52b2b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col],lam = yeojohnson(df[col])

# %% [markdown]
# ## Finding how skewness changed after normalization methods

# %%
mean_skew = list()
for col in df.columns:
  if col == 'Class':
    continue
  mean_skew.append(np.abs(df[col].skew()))
print(f'The mean of skewness:{round(sum(mean_skew)/len(mean_skew),2)}')
# Out:
# The mean of skewness:0.68

# %%
colors = ['#B3F9C5', '#f9c5b3']
#first row
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V1'],ax=ax1,color = 'purple')
ax1.set_title('V1')
sns.distplot(df['V2'],ax=ax2,color = 'magenta')
ax2.set_title('V2')
#second
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V3'],ax=ax1,color = 'blue')
ax1.set_title('V3')
sns.distplot(df['V5'],ax=ax2,color='purple')
ax2.set_title('V5')
#third
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V6'],ax=ax1,color = 'blue')
ax1.set_title('V6')
sns.distplot(df['V7'],ax=ax2,color='purple')
ax2.set_title('V7')
#fourth
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V8'],ax=ax1,color = 'blue')
ax1.set_title('V8')
sns.distplot(df['V10'],ax=ax2,color='purple')
ax2.set_title('V10')
#fifth
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V12'],ax=ax1,color = 'blue')
ax1.set_title('V12')
sns.distplot(df['V14'],ax=ax2,color='purple')
ax2.set_title('V14')
#sixth
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V16'],ax=ax1,color = 'blue')
ax1.set_title('V16')
sns.distplot(df['V17'],ax=ax2,color='purple')
ax2.set_title('V17')
#seventh
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V20'],ax=ax1,color = 'blue')
ax1.set_title('V20')
sns.distplot(df['V21'],ax=ax2,color='purple')
ax2.set_title('V21')
#eight
f,(ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
sns.distplot(df['V23'],ax=ax1,color = 'blue')
ax1.set_title('V23')
sns.distplot(df['V28'],ax=ax2,color='purple')
ax2.set_title('V28')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'V28')

# %%
df

# %%
skewed_cols = []
for cols in df.columns:
  if df[cols].dtype != 'object':
    if np.abs(df[cols].skew()) > 1:
      skewed_cols.append(cols)
print(skewed_cols)
# Out:
# ['V5', 'V6', 'V7', 'V17', 'V20', 'V21', 'V23', 'V28', 'Class']

# %% [markdown]
# # Modelling with Keras

# %%
y = df.iloc[:,-2]
X = df.drop('Class',axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 42,test_size = 0.3)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (198608, 29)
# (85118, 29)
# (198608,)
# (85118,)

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# ## The Small Model

# %%
from keras.layers import Dense
from keras.layers import Dropout
from keras.models import Sequential
import tensorflow as tf
from keras.callbacks import EarlyStopping

# %%
small_model = Sequential()

# %%
small_model.add(Dense(units = 32,activation='relu',input_shape=(29,)))
small_model.add(Dense(units = 64,activation = 'relu'))
small_model.add(Dense(units = 1,activation = 'sigmoid'))

# %%
small_model_history = small_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001 ),
                    metrics = ['accuracy'],
                    loss = tf.keras.losses.BinaryCrossentropy())

small_model_history = small_model.fit(X_train,y_train,
                batch_size = 64,
                epochs = 10
                )
# Out:
# Epoch 1/10
# 3104/3104 [==============================] - 18s 4ms/step - loss: 0.0099 - accuracy: 0.9971
# Epoch 2/10
# 3104/3104 [==============================] - 12s 4ms/step - loss: 0.0029 - accuracy: 0.9994
# Epoch 3/10
# 3104/3104 [==============================] - 12s 4ms/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 4/10
# 3104/3104 [==============================] - 13s 4ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 5/10
# 3104/3104 [==============================] - 13s 4ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 6/10
# 3104/3104 [==============================] - 13s 4ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 7/10
# 3104/3104 [==============================] - 13s 4ms/step - loss: 0.0019 - accuracy: 0.9996
# Epoch 8/10
# 3104/3104 [==============================] - 13s 4ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 9/10
# 3104/3104 [==============================] - 13s 4ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 10/10
# 3104/3104 [==============================] - 13s 4ms/step - loss: 0.0017 - accuracy: 0.9996

# %%
test_loss,test_accuracy = small_model.evaluate(X_test,y_test)
train_loss,train_accuracy = small_model.evaluate(X_train,y_train)
print(f"Test accuracy:{round(test_accuracy * 100,2)}")
print(f"Train accuracy:{round(train_accuracy * 100,2)}")
# Out:
# 2660/2660 [==============================] - 8s 3ms/step - loss: 0.0034 - accuracy: 0.9992
# 6207/6207 [==============================] - 20s 3ms/step - loss: 0.0015 - accuracy: 0.9996
# Test accuracy:99.92
# Train accuracy:99.96

# %%
small_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 32)                960
#
#  dense_7 (Dense)             (None, 64)                2112
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 3,137
# Trainable params: 3,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions = small_model.predict(X_test)
# Out:
# 2660/2660 [==============================] - 9s 3ms/step

# %%
predictions
# Out:
# array([[1.1355443e-06],
#        [1.2732065e-12],
#        [2.5695751e-08],
#        ...,
#        [6.4415656e-07],
#        [2.3661061e-05],
#        [8.3495377e-07]], dtype=float32)

# %%
#we have to convert predictions to the 0 and 1's we din't need any probability|

# %%
np.unique(np.round(predictions))
# Out:
# array([0., 1.], dtype=float32)

# %%
from sklearn.utils.multiclass import type_of_target
type_of_target(predictions)
# Out:
# 'continuous'

# %%
type_of_target(y_test)
# Out:
# 'binary'

# %%
#we can't any predict in the evaluation metrics with 'binary' and 'continuous' dtypes 
#that is why i converted probabilties to the discrete values

# %%
print(y_test.shape)
print(predictions.ndim)
# Out:
# (85118,)
# 2

# %%
print(predictions.shape)
print(predictions.ndim)
# Out:
# (85118, 1)
# 2

# %%
from sklearn.metrics import ConfusionMatrixDisplay,confusion_matrix
#fig,ax = plt.subplots(figsize=(16,9))
confusion_matrix(y_test,np.round(predictions))
#plt.show()
# Out:
# array([[84981,     3],
#        [   61,    73]])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,np.round(predictions)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84984
#            1       0.96      0.54      0.70       134
#
#     accuracy                           1.00     85118
#    macro avg       0.98      0.77      0.85     85118
# weighted avg       1.00      1.00      1.00     85118

# %% [markdown]
# ## The Improved Model

# %%
#I use Dropout Layer,Regularizations Method,Incrase the number of Hidden layers and Callback method

# %%
from keras.backend import dropout
from keras import regularizers

improved_model = Sequential()

improved_model.add(Dense(units = 16,kernel_regularizer = regularizers.l2(0.001),activation='relu',input_shape=(29,)))
improved_model.add(Dropout(0.5))
improved_model.add(Dense(units = 32,kernel_regularizer= regularizers.l2(0.001),activation = 'relu'))
improved_model.add(Dropout(0.5))
improved_model.add(Dense(units = 1,activation = 'sigmoid'))

improved_model_history = improved_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01 ),
                    metrics = ['accuracy'],
                    loss = tf.keras.losses.BinaryCrossentropy())
improved_model_history = small_model.fit(X_train,y_train,
                batch_size = 256,
                epochs = 10,
                validation_split = 0.2,
                callbacks=EarlyStopping(patience=3)
                )
# Out:
# Epoch 1/10
# 621/621 [==============================] - 5s 8ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0015 - val_accuracy: 0.9997
# Epoch 2/10
# 621/621 [==============================] - 7s 11ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0017 - val_accuracy: 0.9996
# Epoch 3/10
# 621/621 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0017 - val_accuracy: 0.9996
# Epoch 4/10
# 621/621 [==============================] - 6s 10ms/step - loss: 9.6467e-04 - accuracy: 0.9997 - val_loss: 0.0018 - val_accuracy: 0.9996

# %%
test_loss,test_accuracy = improved_model.evaluate(X_test,y_test)
train_loss,train_accuracy = improved_model.evaluate(X_train,y_train)
print(f"Test accuracy:{round(test_accuracy * 100,2)}")
print(f"Train accuracy:{round(train_accuracy * 100,2)}")
# Out:
# 2660/2660 [==============================] - 11s 4ms/step - loss: 0.7973 - accuracy: 0.3923
# 6207/6207 [==============================] - 31s 5ms/step - loss: 0.7969 - accuracy: 0.3910
# Test accuracy:39.23
# Train accuracy:39.1

# %%
improved_model_predictions = improved_model.predict(X_test)
confusion_matrix(y_test,np.round(improved_model_predictions))

# %%
print(classification_report(y_test,np.round(improved_model_predictions)))

# %% [markdown]
# ## Oversample model with duplicate values

# %%
# class count
class_count_0 = df['Class'].value_counts().values[0]
class_count_1 = df['Class'].value_counts().values[1]

# Separate class
class_0 = df[df['Class'] == 0]
class_1 = df[df['Class'] == 1]
print('class 0:', class_0.shape)
print('class 1:', class_1.shape)

# %%
class_1_over = class_1.sample(class_count_0, replace=True)

test_over = pd.concat([class_1_over, class_0], axis=0)
print("total class of 1 and 0:\n",test_over['Class'].value_counts())

plt.figure(figsize=(16,9))
test_over['Class'].value_counts().plot(kind='bar', title='count (target)')
plt.show()
# Out:
# total class of 1 and 0:
#  1    283253
# 0    283253
# Name: Class, dtype: int64

# %%
test_over.shape
# Out:
# (566506, 30)

# %%
X = test_over.drop('Class',axis=1)
y = test_over.iloc[:,-2]

# %%
X_over_train,X_over_test,y_over_train,y_over_test = train_test_split(X,y,random_state=101,test_size=0.2)

# %%
over_model = Sequential()

over_model.add(Dense(units = 16,kernel_regularizer = regularizers.l2(0.001),activation='relu',input_shape=(29,)))
over_model.add(Dropout(0.5))
over_model.add(Dense(units = 32,kernel_regularizer= regularizers.l2(0.001),activation = 'relu'))
over_model.add(Dropout(0.5))
over_model.add(Dense(units = 1,activation = 'sigmoid'))

over_model_history = over_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01 ),
                    metrics = ['accuracy'],
                    loss = tf.keras.losses.BinaryCrossentropy())
over_model_history = over_model.fit(X_over_train,y_over_train,
                batch_size = 64,
                epochs = 10,
                validation_split = 0.2,
                #callbacks=EarlyStopping(patience=3)
                )
# Out:
# Epoch 1/10
# 5666/5666 [==============================] - 33s 5ms/step - loss: 0.1677 - accuracy: 0.9455 - val_loss: 0.1106 - val_accuracy: 0.9668
# Epoch 2/10
# 5666/5666 [==============================] - 24s 4ms/step - loss: 0.1614 - accuracy: 0.9465 - val_loss: 0.1118 - val_accuracy: 0.9668
# Epoch 3/10
# 5666/5666 [==============================] - 26s 5ms/step - loss: 0.1629 - accuracy: 0.9378 - val_loss: 0.1128 - val_accuracy: 0.9519
# Epoch 4/10
# 5666/5666 [==============================] - 26s 5ms/step - loss: 0.1664 - accuracy: 0.9356 - val_loss: 0.1264 - val_accuracy: 0.9549
# Epoch 5/10
# 5666/5666 [==============================] - 23s 4ms/step - loss: 0.1677 - accuracy: 0.9330 - val_loss: 0.1114 - val_accuracy: 0.9569
# Epoch 6/10
# 5666/5666 [==============================] - 24s 4ms/step - loss: 0.1679 - accuracy: 0.9300 - val_loss: 0.1243 - val_accuracy: 0.9510
# Epoch 7/10
# 5666/5666 [==============================] - 29s 5ms/step - loss: 0.1666 - accuracy: 0.9314 - val_loss: 0.1137 - val_accuracy: 0.9500
# Epoch 8/10
# 5666/5666 [==============================] - 24s 4ms/step - loss: 0.1657 - accuracy: 0.9335 - val_loss: 0.1156 - val_accuracy: 0.9565
# Epoch 9/10
# 5666/5666 [==============================] - 25s 4ms/step - loss: 0.1689 - accuracy: 0.9297 - val_loss: 0.1192 - val_accuracy: 0.9451
# Epoch 10/10
# 5666/5666 [==============================] - 25s 4ms/step - loss: 0.1727 - accuracy: 0.9267 - val_loss: 0.1096 - val_accuracy: 0.9676

# %%
test_loss,test_accuracy = improved_model.evaluate(X_test,y_test)
train_loss,train_accuracy = improved_model.evaluate(X_train,y_train)
print(f"Test accuracy:{round(test_accuracy * 100,2)}")
print(f"Train accuracy:{round(train_accuracy * 100,2)}")
# Out:
# 1774/1774 [==============================] - 4s 2ms/step - loss: 0.8827 - accuracy: 0.2555
# 7094/7094 [==============================] - 18s 3ms/step - loss: 0.8817 - accuracy: 0.2558
# Test accuracy:25.55
# Train accuracy:25.58

# %%
#we have so many duplicate values that is why our model isn't good

# %%
improved_model_predictions = improved_model.predict(X_test)
confusion_matrix(y_test,np.round(improved_model_predictions))
# Out:
# 1774/1774 [==============================] - 3s 1ms/step
# array([[14428, 42228],
#        [   20,    70]])

# %%
print(classification_report(y_test,np.round(improved_model_predictions)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.25      0.41     56656
#            1       0.00      0.78      0.00        90
#
#     accuracy                           0.26     56746
#    macro avg       0.50      0.52      0.20     56746
# weighted avg       1.00      0.26      0.41     56746

# %% [markdown]
# # Oversampling and Undersampling Methods

# %% [markdown]
# ## Over Sampling with SMOTE

# %%
from imblearn.combine import SMOTEENN,SMOTETomek
from sklearn.model_selection import StratifiedKFold
from imblearn.pipeline import Pipeline as pp
from imblearn.over_sampling import SMOTE

# %%
def base_model():
  models = []
  models.append(small_model)
  models.append(improved_model)
  models.append(over_model)
  return models

# %%
models = base_model()
models
# Out:
# [<keras.engine.sequential.Sequential at 0x7fc90c8b3ee0>,
#  <keras.engine.sequential.Sequential at 0x7fc87c4be340>,
#  <keras.engine.sequential.Sequential at 0x7fc906699a00>]

# %%
metrics = ['precision', 'recall', 'f1', 'average Precision-Recall (AUPRC)']

# %%
results = {model.__class__.__name__: {metric: [] for metric in metrics} for model in models}

# %%
#fit the models with SMOTE valuate the models on test data

# %%
from sklearn.metrics import precision_score,recall_score,f1_score,average_precision_score
# loop through each model
for model in models:
    # fit the model without SMOTE
    model.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = model.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))
    
    # fit the model with SMOTE
    pipe = pp([('smote', SMOTE(random_state=0)), ('model', model)])
    pipe.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = pipe.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))
# Out:
# 7094/7094 [==============================] - 25s 4ms/step - loss: 0.0016 - accuracy: 0.9996
# 1774/1774 [==============================] - 4s 2ms/step
# 14163/14163 [==============================] - 50s 4ms/step - loss: 0.0028 - accuracy: 0.9993
# 1774/1774 [==============================] - 3s 1ms/step
# 7094/7094 [==============================] - 30s 4ms/step - loss: 0.0170 - accuracy: 0.9980
# 1774/1774 [==============================] - 3s 2ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 14163/14163 [==============================] - 52s 4ms/step - loss: 0.3383 - accuracy: 0.8913
# 1774/1774 [==============================] - 3s 1ms/step
# 7094/7094 [==============================] - 27s 4ms/step - loss: 0.0163 - accuracy: 0.9984
# 1774/1774 [==============================] - 3s 1ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 14163/14163 [==============================] - 55s 4ms/step - loss: 0.5891 - accuracy: 0.6607
# 1774/1774 [==============================] - 3s 1ms/step

# %%
# print the evaluation results
print("Evaluation results:")
print("\n")
for model_name, model_results in results.items():
    print("-------------------")
    print("Model:", model_name)
    print("-------------------")
    
    for metric, scores in model_results.items():
    
        print( metric,": " "without SMOTE:", scores[0], "|| " "with SMOTE:", scores[1])
    print("\n")
# Out:
# Evaluation results:
#
#
# -------------------
# Model: Sequential
# -------------------
# precision : without SMOTE: 0.9242424242424242 || with SMOTE: 0.8974358974358975
# recall : without SMOTE: 0.6777777777777778 || with SMOTE: 0.7777777777777778
# f1 : without SMOTE: 0.8333333333333333 || with SMOTE: 0.8220858895705521
# average Precision-Recall (AUPRC) : without SMOTE: 0.6983581457553191 || with SMOTE: 0.6836625447446366

# %% [markdown]
# ## Evaulate Oversampling with Adasyn

# %%
from imblearn.over_sampling import ADASYN

# split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# list of metrics to be evaluated
metrics = ['precision', 'recall', 'f1', 'average Precision-Recall (AUPRC)']

# dictionary to store evaluation results
results = {model.__class__.__name__: {metric: [] for metric in metrics} for model in models}

# loop through each model
for model in models:
    # fit the model without ADASYN
    model.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = model.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))
    
    # fit the model with ADASYN
    pipe = pp([('ADASYN', ADASYN(random_state=0)), ('model', model)])
    pipe.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = pipe.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))
# Out:
# 6207/6207 [==============================] - 22s 4ms/step - loss: 0.0030 - accuracy: 0.9996
# 2660/2660 [==============================] - 4s 1ms/step
# 12393/12393 [==============================] - 44s 4ms/step - loss: 0.0059 - accuracy: 0.9986
# 2660/2660 [==============================] - 4s 1ms/step
# 6207/6207 [==============================] - 26s 4ms/step - loss: 0.0247 - accuracy: 0.9960
# 2660/2660 [==============================] - 10s 4ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 12393/12393 [==============================] - 55s 4ms/step - loss: 0.7008 - accuracy: 0.4989
# 2660/2660 [==============================] - 8s 3ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6207/6207 [==============================] - 31s 5ms/step - loss: 0.0208 - accuracy: 0.9967
# 2660/2660 [==============================] - 5s 2ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 12393/12393 [==============================] - 47s 4ms/step - loss: 0.7052 - accuracy: 0.4999
# 2660/2660 [==============================] - 4s 1ms/step

# %%
# print the evaluation results
print("Evaluation results:")
print("\n")
for model_name, model_results in results.items():
    print("-------------------")
    print("Model:", model_name)
    print("-------------------")
    
    for metric, scores in model_results.items():
    
        print( metric,": " "without ADASYN:", scores[0], "|| " "with ADASYN:", scores[1])
    print("\n")
# Out:
# Evaluation results:
#
#
# -------------------
# Model: Sequential
# -------------------
# precision : without ADASYN: 0.9032258064516129 || with ADASYN: 0.5087719298245614
# recall : without ADASYN: 0.8682170542635659 || with ADASYN: 0.8992248062015504
# f1 : without ADASYN: 0.8853754940711462 || with ADASYN: 0.6498599439775911
# average Precision-Recall (AUPRC) : without ADASYN: 0.7843957717500993 || with ADASYN: 0.45765306914975074

# %% [markdown]
# ## Undersampling Evaulation with ENN(Editet Nearest Neighbours)

# %%
from imblearn.under_sampling import EditedNearestNeighbours

# list of metrics to be evaluated
metrics = ['precision', 'recall', 'f1', 'average Precision-Recall (AUPRC)']

# dictionary to store evaluation results
results = {model.__class__.__name__: {metric: [] for metric in metrics} for model in models}

# loop through each model
for model in models:
    # fit the model without EditedNearestNeighbours
    model.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = model.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))
    
    # fit the model with EditedNearestNeighbours
    pipe = pp([('EditedNearestNeighbours', EditedNearestNeighbours()), ('model', model)])
    pipe.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = pipe.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))
# Out:
# 6207/6207 [==============================] - 26s 4ms/step - loss: 0.0013 - accuracy: 0.9996
# 2660/2660 [==============================] - 4s 1ms/step
# 6203/6203 [==============================] - 22s 4ms/step - loss: 9.3017e-04 - accuracy: 0.9998
# 2660/2660 [==============================] - 4s 1ms/step
# 6207/6207 [==============================] - 24s 4ms/step - loss: 0.0213 - accuracy: 0.9983
# 2660/2660 [==============================] - 4s 2ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6203/6203 [==============================] - 23s 4ms/step - loss: 0.0128 - accuracy: 0.9983
# 2660/2660 [==============================] - 4s 2ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6207/6207 [==============================] - 24s 4ms/step - loss: 0.0214 - accuracy: 0.9979
# 2660/2660 [==============================] - 4s 1ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6203/6203 [==============================] - 23s 4ms/step - loss: 0.0128 - accuracy: 0.9983
# 2660/2660 [==============================] - 4s 1ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# print the evaluation results
print("Evaluation results:")
print("\n")
for model_name, model_results in results.items():
    print("-------------------")
    print("Model:", model_name)
    print("-------------------")
    
    for metric, scores in model_results.items():
    
        print( metric,": " "without ENN:", scores[0], "|| " "with ENN:", scores[1])
    print("\n")
# Out:
# Evaluation results:
#
#
# -------------------
# Model: Sequential
# -------------------
# precision : without ENN: 0.8482142857142857 || with ENN: 0.7253521126760564
# recall : without ENN: 0.7364341085271318 || with ENN: 0.7984496124031008
# f1 : without ENN: 0.7883817427385893 || with ENN: 0.7601476014760148
# average Precision-Recall (AUPRC) : without ENN: 0.6250533768156704 || with ENN: 0.5794625715269088

# %% [markdown]
# ## Evaluating Combined Methods with SMOTEENN

# %%
from imblearn.combine import SMOTEENN


# list of metrics to be evaluated
metrics = ['precision', 'recall', 'f1', 'average Precision-Recall (AUPRC)']

# dictionary to store evaluation results
results = {model.__class__.__name__: {metric: [] for metric in metrics} for model in models}

# loop through each model
for model in models:
    # fit the model without SMOTEENN
    model.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = model.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))
    
    # fit the model with SMOTEENN
    pipe = pp([('SMOTEENN', SMOTEENN()), ('model', model)])
    pipe.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = pipe.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))
# Out:
# 6207/6207 [==============================] - 31s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# 2660/2660 [==============================] - 5s 2ms/step

# %%
# print the evaluation results
print("Evaluation results:")
print("\n")
for model_name, model_results in results.items():
    print("-------------------")
    print("Model:", model_name)
    print("-------------------")
    
    for metric, scores in model_results.items():
    
        print( metric,": " "without SMOTEENN:", scores[0], "|| " "with SMOTEENN:", scores[1])
    print("\n")

# %% [markdown]
# ## Evaluating Combined Methods with SMOTETomek

# %%
from imblearn.combine import SMOTETomek

# list of metrics to be evaluated
metrics = ['precision', 'recall', 'f1', 'average Precision-Recall (AUPRC)']

# dictionary to store evaluation results
results = {model.__class__.__name__: {metric: [] for metric in metrics} for model in models}

# loop through each model
for model in models:
    # fit the model without SMOTEENN
    model.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = model.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))
    
    # fit the model with SMOTEENN
    pipe = pp([('SMOTETomek', SMOTETomek()), ('model', model)])
    pipe.fit(X_train, y_train)
    # evaluate the model on test data
    y_pred = pipe.predict(X_test)
    results[model.__class__.__name__]['precision'].append(precision_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['recall'].append(recall_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['f1'].append(f1_score(y_test, np.round(y_pred)))
    results[model.__class__.__name__]['average Precision-Recall (AUPRC)'].append(average_precision_score(y_test, np.round(y_pred)))

# %%
# print the evaluation results
print("Evaluation results:")
print("\n")
for model_name, model_results in results.items():
    print("-------------------")
    print("Model:", model_name)
    print("-------------------")
    
    for metric, scores in model_results.items():
    
        print( metric,": " "without SMOTETomek:", scores[0], "|| " "with SMOTETomek:", scores[1])
    print("\n")

# %% [markdown]
# # Modelling with Stradified-k fold

# %%
from sklearn.model_selection import StratifiedKFold
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.081838 -0.072223  3.301464  1.378155 -0.336786  0.436565  0.239426
# 1   0.0  1.483345  0.273359  0.170994  0.448154  0.060070 -0.083315 -0.078823
# 2   1.0 -1.080876 -1.208020  2.177630  0.379780 -0.499950  1.520333  0.789827
# 3   1.0 -0.810006 -0.181757  2.205573 -0.863291 -0.010307  1.095768  0.237439
# 4   2.0 -0.945580  0.947300  1.865334  0.403034 -0.405012  0.094653  0.591980
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.100070  0.363787  ...  0.277838 -0.110043  0.066928  0.128539 -0.189115
# 1  0.086125 -0.255425  ... -0.638672  0.101653 -0.339846  0.167170  0.125895
# 2  0.256045 -1.514654  ...  0.771679  0.933712 -0.689281 -0.327642 -0.139097
# 3  0.396374 -1.387024  ...  0.005274 -0.189074 -1.175575  0.647376 -0.221929
# 4 -0.261050  0.817739  ...  0.798278 -0.136797  0.141267 -0.206010  0.502292
#
#         V27       V28    Amount  Class  normalized_amount
# 0  0.133558 -0.021082  4.493777      0           2.175019
# 1 -0.008983  0.014710  1.268358      0           0.431364
# 2 -0.055353 -0.059980  5.218064      0           2.578261
# 3  0.062723  0.061218  4.340826      0           2.091702
# 4  0.219422  0.212364  3.882043      0           1.845098
#
# [5 rows x 32 columns]

# %%
ratio = sum(df['Class'])/len(df)

# %%
print(f"Class ratio:{ratio}")
# Out:
# Class ratio:0.001667101358352777

# %%
from sklearn.model_selection import StratifiedGroupKFold
from imblearn.under_sampling import NearMiss
#from imblearn.pipeline import make_pipeline as imbalanced_make_pipeline
from sklearn.metrics import roc_auc_score
from collections import Counter

undersample_X = df.drop('Class', axis=1)
undersample_y = df['Class']

sss = StratifiedGroupKFold(n_splits=5,shuffle=True)
for train_index, test_index in sss.split(X, y):
    print("Train:", train_index, "Test:", test_index)
    original_Xtrain, original_Xtest = X.iloc[train_index], X.iloc[test_index]
    original_ytrain, original_ytest = y.iloc[train_index], y.iloc[test_index]

for train_index, test_index in sss.split(undersample_X, undersample_y):
    print("Train:", train_index, "Test:", test_index)
    undersample_Xtrain, undersample_Xtest = undersample_X.iloc[train_index], undersample_X.iloc[test_index]
    undersample_ytrain, undersample_ytest = undersample_y.iloc[train_index], undersample_y.iloc[test_index]
    
undersample_Xtrain = undersample_Xtrain.values
undersample_Xtest = undersample_Xtest.values
undersample_ytrain = undersample_ytrain.values
undersample_ytest = undersample_ytest.values 

undersample_accuracy = []
undersample_precision = []
undersample_recall = []
undersample_f1 = []
undersample_auc = []

# Implementing NearMiss Technique 
# Distribution of NearMiss (Just to see how it distributes the labels we won't use these variables)
X_nearmiss, y_nearmiss = NearMiss().fit_resample(undersample_X.values, undersample_y.values)
print('NearMiss Label Distribution: {}'.format(Counter(y_nearmiss)))
# Cross Validating the right way

for train, test in sss.split(undersample_Xtrain, undersample_ytrain):
    undersample_pipeline = pp(NearMiss(,improved_model) # SMOTE happens during Cross Validation not before..
    undersample_model = undersample_pipeline.fit(undersample_Xtrain[train], undersample_ytrain[train])
    undersample_prediction = undersample_pipeline.predict(undersample_Xtrain[test])
    
    undersample_accuracy.append(undersample_pipeline.score(original_Xtrain[test], original_ytrain[test]))
    undersample_precision.append(precision_score(original_ytrain[test], undersample_prediction))
    undersample_recall.append(recall_score(original_ytrain[test], undersample_prediction))
    undersample_f1.append(f1_score(original_ytrain[test], undersample_prediction))
    undersample_auc.append(roc_auc_score(original_ytrain[test], undersample_prediction))
# Out:
# Train: [     0      1      2 ... 283723 283724 283725] Test: []
# Train: [     0      1      2 ... 283723 283724 283725] Test: []
# Train: [     1      2      3 ... 283723 283724 283725] Test: [0]
# Train: [     0      1      2 ... 283723 283724 283725] Test: []
# Train: [     0      1      2 ... 283723 283724 283725] Test: []
# Train: [     0      1      2 ... 283723 283724 283725] Test: []
# Train: [     0      1      2 ... 283723 283724 283725] Test: []
# Train: [     1      2      3 ... 283723 283724 283725] Test: [0]
# Train: [     0      1      2 ... 283723 283724 283725] Test: []
# Train: [     0      1      2 ... 283723 283724 283725] Test: []
# NearMiss Label Distribution: Counter({0: 473, 1: 473})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-ada1ee7d95e1> in <module>
#      37
#      38 for train, test in sss.split(undersample_Xtrain, undersample_ytrain):
# ---> 39     undersample_pipeline = pp(NearMiss(sampling_strategy='majority'), improved_model) # SMOTE happens during Cross Validation not before..
#      40     undersample_model = undersample_pipeline.fit(undersample_Xtrain[train], undersample_ytrain[train])
#      41     undersample_prediction = undersample_pipeline.predict(undersample_Xtrain[test])
#
# TypeError: __init__() takes 2 positional arguments but 3 were given

# %%
from sklearn.metrics import plot_confusion_matrix

labels = ['No Fraud', 'Fraud']

fig = plt.figure(figsize=(16,8))

small_model_matrix = confusion_matrix(y_test,np.round(predictions))
improved_model_matrix = confusion_matrix(y_test,np.round(improved_model_predictions))
over_model_matrix = confusion_matrix(y_test,np.round(over_model_predictions))


#small_model
fig.add_subplot(221)
sns.heatmap(confusion_matrix(y_test,np.round(predictions)),annot=True)

#improved_model
fig.add_subplot(222)
sns.heatmap(improved_model_predictions,annot=True)

#after oversampling
fig.add_subplot(223)
sns.heatmap(over_model_matrix,annot=True)

plt.show()
